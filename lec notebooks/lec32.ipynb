# %%
from datascience import *
import numpy as np

import matplotlib.pyplot as plots
from mpl_toolkits.mplot3d import Axes3D
plots.style.use('fivethirtyeight')
# %matplotlib inline

# %% [markdown]
# ## Classification Examples: Medicine

# %% [markdown]
# #### Watch Demo Video Below

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('D_E4b0QG_fY', width=800, height=300)

# %% [markdown]
# **Please run all cells before this cell, including the import cell at the top of the notebook.**

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('AqOPmNjjA6A', width=800, height=300)

# %%
ckd = Table.read_table('ckd.csv').relabeled('Blood Glucose Random', 'Glucose')
ckd.show(3)

# %%
ckd.group('Class')

# %%
ckd.scatter('White Blood Cell Count', 'Glucose', colors='Class')

# %%
ckd.scatter('Hemoglobin', 'Glucose', colors='Class')

# %% [markdown]
# ## Classification Examples: Counterfeit Banknotes

# %% [markdown]
# #### Watch Demo Video Below

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('eHdDpemodVc', width=800, height=300)

# %% [markdown]
# **Please run all cells before this cell, including the previous example cells and the import cell at the top of the notebook.**

# %%
banknotes = Table.read_table('banknote.csv')
banknotes

# %%
banknotes.scatter('WaveletVar', 'WaveletCurt', colors='Class')

# %%
banknotes.scatter('WaveletSkew', 'Entropy', colors='Class')

# %%
fig = plots.figure(figsize=(8,8))
ax = Axes3D(fig)
ax.scatter(banknotes.column('WaveletSkew'), 
           banknotes.column('WaveletVar'), 
           banknotes.column('WaveletCurt'), 
           c=banknotes.column('Class'),
           cmap='viridis',
           s=50);
